# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse=sum((y-yp)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 236.276
# The Mean absolute error is 12.449

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 我選擇拿來練習的資料是Ames Housing dataset。此資料的重要性主要來自於它能讓我們研究房屋交易時主要影響房價的房屋屬性有那些。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# The Ames Housing dataset was compiled by Dean De Cock for use in data science education
# 3. 蒐集而來的資料型態為何
# 都有20 continuous variables relate to various area dimensions for each observation，14 discrete variables typically quantify the number of items occurring within the house，23 nominal variables typically identify various types of dwellings, garages, materials, and environmental conditions，23 ordinal variables typically rate various items within the property
# 4. 這組資料想解決的問題如何評估
# 以所提供房屋屬性預測實際交易價格的準確程度( Root-Mean-Squared-Error (RMSE))
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 營收為"量"乘上"價"，要不能讓車隊載到更多客人，要不能載到願付價格更高的客人。
# 或是通過更好的規劃路線來減少車隊所需油費，如果將業績定義為營收扣除成本的話。
# 見第4題
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 從公司拿:過往司機路線、收費、所載人數、時間日期等。
# 跟調研機構買:各區人流、收入、擁有交通工具類型
# 3. 蒐集而來的資料型態為何
# 路線圖、數值資料、時間資料等
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 結合公司的資料與調研機構的資料後我們可以判斷:
# 人流多/收入高/沒車的區域在相同時間段派遣相同數量車子的情況下，是否較多客人/較高價錢
# 各區域在派遣相同數量車子的情況下，那些時間段客人較多/較高價錢
# 各時間段在派遣相同數量車子的情況下，那些區域客人較多/較高價錢
# 因此在給定時段、各車所處位置後，能動態調整各車位置、並判斷接特定客人單，讓車隊整體在一整天賺到最多
